# %%
dbutils.widgets.text("catalog_name","")

# %%
catalog_name = dbutils.widgets.get("catalog_name")

# %%
# %sql
select * from losdata.information_schema.columns

# %%
spark.sql(f"select * from {catalog_name}.information_schema.columns").display()
